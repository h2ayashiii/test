# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
from sklearn.datasets import load_boston
 
boston = load_boston()
X_array = boston.data
y_array = boston.target
df = pd.DataFrame(X_array, columns = boston.feature_names).assign(Price=np.array(y_array))
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  Price
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0000)
df_train, df_valid = train_test_split(df_train, test_size=0.2, random_state=0000)

X_train = df_train.drop('Price', axis = 1)
y_train = df_train['Price']
X_valid = df_valid.drop('Price', axis = 1)
y_valid = df_valid['Price']
X_test = df_test.drop('Price', axis = 1)
y_test = df_test['Price']

lgb_train = lgb.Dataset(X_train, y_train)
lgb_valid = lgb.Dataset(X_valid, y_valid)
lgb_test = lgb.Dataset(X_test, y_test)

# %%
params = {'task': 'train',
          'objective': 'regression',
          'boosting': 'gbdt',
          'metric' : 'rmse',
          'verbosity': -1}

evals_result = {}
lgm_model = lgb.train(params,
                      lgb_train,
                      valid_sets=lgb_valid,
                      valid_names=['train-data', 'valid-data'],
                      num_boost_round=1000,
                      early_stopping_rounds=100,
                      evals_result=evals_result,
                      verbose_eval=100)
# Out:
# Training until validation scores don't improve for 100 rounds
# [100]	train-data's rmse: 3.01245
# [200]	train-data's rmse: 2.87943
# [300]	train-data's rmse: 2.82316
# [400]	train-data's rmse: 2.80081
# [500]	train-data's rmse: 2.79983
# [600]	train-data's rmse: 2.79548
# [700]	train-data's rmse: 2.79582
# Early stopping, best iteration is:
# [623]	train-data's rmse: 2.79252

# %%
y_pred = gbm.predict(X_test)
df_pred = pd.concat([y_test.reset_index(drop=True), pd.Series(y_pred)], axis=1)
df_pred.columns = ['true', 'pred']

df_pred.head()
# Out:
#    true       pred
# 0  22.6  24.538950
# 1  50.0  25.392688
# 2  23.0  23.782589
# 3   8.3   9.981334
# 4  21.2  20.622665

# %%
def Prediction_accuracy(predicted_df):
    RMSE = np.sqrt(mean_squared_error(df_pred['true'], df_pred['pred']))
    plt.figure(figsize = (10,10))
    ax = plt.subplot(111)
    ax.scatter('true', 'pred', data = df_pred)
    ax.set_xlabel('True', fontsize = 20)
    ax.set_ylabel('Pred', fontsize = 20)
    plt.tick_params(labelsize = 15)
    x = np.linspace(5, 50)
    y = x
    ax.plot(x, y, 'r-')
    plt.text(0.1, 0.9, 'RMSE = {}'.format(str(round(RMSE,3))),transform = ax.transAxes, fontsize = 15)

Prediction_accuracy(predicted_df)
